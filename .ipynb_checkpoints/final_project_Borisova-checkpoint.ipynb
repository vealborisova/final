# %% [markdown]
# # **Разработка системы семантического поиска в базе знаний для системы поддержки**

# %% [markdown]
# **Постановка задачи**

# %% [markdown]
# Исследовать различные методы поиска необходимой инструкции в базе знаний по вопросу пользователя.

# %% [markdown]
# # Этапы работы
# 1. создание датасета на основе данных вопрос->инструкция
# 2. получение векторных представлений вопросов и инструкций с помощью BERT и TF-IDF
# 3. с помощью векторных представлений анализ расстояний между вопросами и инструкциями
# 3. классификация вопросов пользователей на полученных эмбеддингах
# 4. создание аналога рекомендательной системы, где на вопрос пользователя предлагается "K" инструкций, в которых он может найти решение своей проблемы.
#
# Метрики:
# - в качестве меры близости векторов используем косинусное расстояние и манхеттенское расстояние;
# - в качестве метрики ранжирования используем map@K

# %% [markdown]
# **Данные**

# %% [markdown]
# Инструкции по решению частых проблем пользователей: https://docs.amvera.ru/general/faq.html. Список вопросов пользователей сформировать на основе анализа канала поддержки: https://t.me/amverachat.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
from transformers import AutoTokenizer, AutoModel
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import torch.nn as nn
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F
from tqdm.auto import tqdm
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Получение данных

# %%
url = 'https://docs.amvera.ru/'
general_page = 'general/'
faq_page = 'faq.html'

# %%
page = requests.get(url + general_page + faq_page)

# %%
print(page.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(page.text, "html.parser", from_encoding='utf-8')
# Out:
# /usr/local/lib/python3.11/dist-packages/bs4/__init__.py:339: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn(

# %%
links = [a.get('href') for a in soup.select("div[class^='toctree-wrapper compound'] > ul > li > a")]

# %%
links
# Out:
# ['FAQ/errors-in-logs.html',
#  'FAQ/update.html',
#  'FAQ/data-saving.html',
#  'FAQ/502-503-error.html',
#  'FAQ/infinite-build-run.html',
#  'FAQ/tgbot.html',
#  'FAQ/enverror.html',
#  'FAQ/not-found-file.html',
#  'FAQ/UTC-time.html',
#  '../applications/git/freq-errors.html',
#  'FAQ/payments.html']

# %%
instr_data = pd.DataFrame()
instr_data['link'] = pd.Series(links).apply(lambda item: list(re.split('[/.]', item))[-2])

# %%
articles = []
for l in links:
    if l[:3] == '../':
        part_of_link = ''
    else:
        part_of_link = general_page
    full_link = url+part_of_link+l.lstrip('../')
    #print(full_link)
    page = requests.get(full_link)
    page.encoding = 'cp1251'
    if page.status_code == 200:
        soup = BeautifulSoup(page.text, "html.parser")
        articles.append(soup.article.get_text().encode('cp1251', 'ignore').decode('utf-8', 'ignore').replace('¶', ''))

# %%
instr_data['row_article'] = pd.Series(np.array(articles))

# %%
pd.set_option('display.max_colwidth', 2000)

# %% [markdown]
# DataFrame instr_data содержит название инструкции и ее текстовое содержание

# %%
instr_data
# Out:
#                   link  \
# 0       errors-in-logs
# 1               update
# 2          data-saving
# 3        502-503-error
# 4   infinite-build-run
# 5                tgbot
# 6             enverror
# 7       not-found-file
# 8             UTC-time
# 9          freq-errors
# 10            payments
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         row_article
# 0   \n\nОшибки в логах и их причины\nНа данной странице собраны самые основные и популярные ошибки, возникающие при деплое приложения различных окружений.\n\nОшибки, актуальные для всех окружений\nСамая распространенная ошибка связана с некорректным указанием пути к базе данных SQLite. Подробно о работе с SQLite здесь: SQLite\n\nRUNNING - FAILED - SUCCEEDED - DELETED в цикле лога приложения (не сборки)\nЕсли статусы в логе приложения (не лог сборки) ушли в подобный бесконечный цикл.\n\nПовысьте тариф до одного из старших. Скорее всего приложению не хватает ресурса, чтобы запуститься. Потом его можно  будет понизить.\nПроверьте, что вы загрузили не пустые файлы. Для этого скачайте код из раздела «Репозиторий» и посмотрите содержимое.\n\nВажно, статус DELETED не является ошибкой работы проекта. Это нормальный статус при сборке и запуске приложения.\n\n\nTerminated by other getupdates request (Телеграм бот)\nЭкземляр бота конфликтует с другим\nНужно:\n\nУбедиться, что выставлен только 1 инстанс. Телеграм боты в режиме опроса не поддерживают горизонтальное масштабирование\nУбедиться, что токен бота больше нигде не используется и бот нигде не запущен.\n\nПроще всего просто сбросить токен в @BotFather\n\n\nPermission denied - не все файлы после заморозки/пересборки проекта удалились/обновились:\nЕсли заморозить проект и сразу же пересобрать, то папка venv в Artifacts, отвечающая за окружение Python, повреждается,\nне успевая удалиться перед новой сборкой, из-за чего возникают ошибки вида:\n\nERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/.local'\n/app/venv/bin/python3: No module named pip.__main__; 'pip' is a package and cannot be directly executed\nError: [Errno 13] Permission denied: '/app/venv'\n\nРешить можно полной очисткой Artifacts. Для этого нужно перейти в «Настройки» и повторно заморозить проект, но на этот раз дать больше времени (около 3 минут) для того, чтобы папка venv успевала удалиться и не вызывала конфликтов во время...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \n\nНе получается обновить проект\nВозможные причины:\n\nНеверная последовательность команд git\nЧастой ошибкой является неверная последовательность команд git (когда проект уже запущен и нужно его обновить)\nСимптомом является ответ команды git, когда вы изменяли код и выполнили git push:\nEverything up-to-date\n\n\nВам поможет следующая последовательность команд:\ngit add .\ngit commit -m "Описание сделанных изменений"\ngit push amvera master\n\n\nНе забудьте про точку в первой команде - она нужна. При этом убедитесь, что файлы, содержащие конфиденциальную информацию (по типу токенов), такие как .env, находятся в .gitignore. Переменные окружения лучше всего указывать именно во вкладке «Переменные» проекта.\n\n\nСборка/развертывание перестала работать\nПроект ранее успешно обновлялся, но в этот раз сборка/развертывание не работает.\nРекомендуем заморозить приложение через интерфейс личного кабинета во вкладке «Настройки», подождать пару минут и повторить\npush/сборку. В ряде случаев данная ошибка может быть вызвана старыми артефактами и их удаление может помочь.\nЕсли ни один из способов выше не помогает, вы можете пересоздать проект с новым именем.\n\nВнимание\nЗаморзка проекта остановит все текущие инстансы приложения без возможности их запуска без пересборки.\n\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        \n\nНе сохраняются данные при перезапуске/пересборке приложения/базы данных\nЕсли при перезапуске/пересборке проекта ваши данные не сохраняются, убедитесь, что вы их сохраняете в каталог /data.\nДанная директория специально создана нами для того, чтобы при перезапусках проектов, пересборке и т.д. все ваши данные\nбыли сохранны и доступны.\nПомимо этого, данные хранимые в /data мы сохраняем в трёх экземплярах на разных узлах кластера, дополнительно делая\nрегулярные бэкапы, что снижает риск их безвозвратной потери.\nЕсли вам неудобно использовать каталог /data, обычно вы можете его изменить в файле amvera.yaml. Например:\n# часть amvera.yml\nrun:\n  persistenceMount: /var/myapp/data\n\n\n\nВажно\nПапка data в корне проекта и директория /data, это разные директории.\nПроверить, что сохранение идет в /data, можно зайдя в папку «data» на странице «Репозиторий».\n\nДля удобства тестирования, вы можете создать директорию /data на локальном компьютере.\nПри развертывании полностью с помощью amvera.yaml, мы не рекомендуем задавать значение run.persistenceMount равной\n/app или его подпапке: это может приводить к некорректному поведению.\nЕсли вы сохраняете в /data базу данных SQLite, ознакомьтесь с инструкцией.\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n
# 3   \n\n502/503 ошибка при статусе «Приложение запущено»\nЕсли развернув проект со статусом «Приложение запущено» вы наблюдаете 503 или 502 ошибку и нет логов, это связано с одной из нижеперечисленных причин.\n\nОшибка 502\nОшибка 502 в нашем случае чаще всего возникает в двух случаях:\n\nОт несоответствия портов, прописанных в коде или команде запуска и портов, прописанных в файле конфигурации (amvera.yaml).\nз-за того, что приложение работает на localhost, вместо 0.0.0.0.\n\nРазберем оба случая более подробно.\n\nПриложение слушает не тот порт\nПо умолчанию в Amvera Cloud открыт порт 80. При разработке веб приложения, вы указываете то, какой порт будет ваше приложение. Обычно это значение port в команде запуска приложения либо в значении параметра метода запуска приложения.\nНапример, если логика запуска вашего приложения в коде выглядит так (пример на Python, Flask):\nif __name__ == "__main__":\n    #...\n    app.run(host="0.0.0.0", port=5000, debug=True)\n\n\nТо в amvera.yml нужно указать в значение параметра containerPort порт 5000.\n# часть amvera.yaml\nrun:\n  containerPort: 5000\n\n\nВместо 5000 можно указать номер порта, который слушает ваше приложение по аналогии.\n\n\nHost не изменен на 0.0.0.0\nОбычно в тех же параметрах запуска приложения указывается адрес (host), на котором будет работать ваше приложение. Как правило, этот параметр несет название host, а его значение по умолчанию - localhost (127.0.0.1— 127.255.255.254).\nЕсли host оставлен в значении localhost(127.0.0.1— 127.255.255.254), а не 0.0.0.0 вы можете получить ошибку 502.\nЕсли это так: поменяйте значение хоста на 0.0.0.0. В таком случае приложение будет работать на всех интерфейсах, а не только на localhost, что и требуется для успешного запуска приложения.\nПример, как должен выглядеть запуск вашего приложения (Python, Flask):\napp.run(host='0.0.0.0', port=ваш порт)\n\n\nЕсли ничего из этого не помогло решить проблему, проверьте, что вы пересобираете проект, а не просто перезапускаете или ...
# 4   \n\nБесконечный запуск, сборка или отсутствие логов\n\nБесконечный запуск\nCопровождается статусом «сборка выполнена успешно, выполняется запуск».\n\nЕсли статус «Выполняется запуск» наблюдается более 5 минут, это свидетельствует об ошибке в конфигурационном файле или его отсутствии, либо о другой ошибке работы приложения.\n\nНеобходимо загрузить Лог приложения. В нем вы найдете лог с «error», который подскажет причину ошибки.\n\nЛибо вашему приложению необходимо использовать более высокий тариф (требуется больше ресурса для запуска). Мы рекомендуем при первой сборке выбрать один из старших тарифов и потом его изменить. После запуска вы сможете изменить тариф в Настройках на тот, при котором приложение работает и который устраивает вас по цене.\n\n\n\nБесконечная сборка\nСборка проектов в Amvera Cloud происходит дольше чем на локальной машине.\nСреднее время сборки составляет 5-20 минут. В редких случаях сборка может происходить до 30-60 минут.\n\nЕсли ваш проект находится в статусе «сборка» больше часа и отсутствуют логи - значит сборка закончилась с ошибкой и стоит убедиться в правильности конфигурационного файла.\n\nОзнакомьтесь с Логом сборки. В нем вы найдете лог с «error», который подскажет причину ошибки.\n\nЛибо вашему приложению необходимо использовать более высокий тариф (требуется больше ресурса для запуска). Мы рекомендуем при первой сборке выбрать один из старших тарифов и потом его изменить. После запуска вы сможете изменить тариф в Настройках на тот, при котором приложение работает и который устраивает вас по цене.\n\n\n\nПроект «завис» при сборке/запуске\nПри этом в интерфейсе не получается им управлять (неактивны кнопки пересборки/перезапуска)\nСимптоматикой данной проблемы является статус сборки/запуска более 30 минут и неактивные кнопки в интерфейсе.\nЭто вызвано либо тем, что ваш проект сложный и требует долгой сборки.\n\nПроверьте Лог сборки и Лог Приложения на наличие ошибок.\nПопробуйте немного подождать (20-30 минут). Некоторые проекты до...
# 5   \n\nНе работает телеграм-бот\nПроверьте Лог сборки и Лог приложения. С высокой вероятностью вы найдете там причину ошибки.\nНиже приведены частые ошибки при развертывании ботов.\n\nБот используется на 2 устройствах\nВо время запуска/перезапуска, инстанс может работать в двух экземплярах около секунды, что может вызывать такого плана ошибку.\nОшибка выглядит следующим образом:\naiogram.utils.exceptions.TerminatedByOtherGetUpdates: Terminated by other getupdates request; make sure that only one bot instance is running\n\n\nПопробуйте поставить delay 2-5 сек на создание объекта, это должно помочь.\n\nПример для бота на Python с использованием telebot\nПеред\nbot = telebot.TeleBot(token) # или подобной строкой\n\n\nПрописать\nimport time\ntime.sleep(5)\n\n\n\n\n\nНеверное название устанавливаемой библиотеки «телебота» в requirements.txt\nТелебот в requirements.txt должен называться pyTelegramBotAPI, а не telebot.\nПосле замены telebot на pyTelegramBotAPI необходимо заморозить проект, воспользовавшись соответсвующее кнопкой на вкладке\n«Настройки».  только после этого пересобирать приложение.\nЗаморозка необходима, чтобы гарантировано очистить кэш, в котором может сохраниться старая зависимость!\n\n\nНет логов\nЕсли статус приложения «Успешно запущено» и проект использует язык Python, то для отображения вывода команды print\nнадо выставить переменную окружения PYTHONUNBUFFERED в 1.\n\n\nВы случайно загрузили папку Venv (для Python)\nЕсли вы используете Python, папку Venv загружать не нужно.\nЗависимости следует устанавливать через requirements.txt\nВы можете составить его через pip freeze, но мы рекомендуем прописать их руками, так как pip freeze дает много лишних зависимостей, что может приводить к конфликтам окружений.\n\n\nЕсли статус проекта «Приложение запущено», но бот молчит\nЧаще всего это связано с тем, что приложение все-таки не успело запуститься и нужно подождать. Если ожидание не помогает, рекомендуется пересобрать проект или поднять тариф.\n\n\nСистема ...
# 6                                   \n\nОшибка venv в Python при сборке или запуске приложения\n\nНесоответствие версии библиотек версии окружения:\nПроблема с тем, что pip (если вы используете Python) находит не те версии библиотеки.\nК примеру: wavelink, если оставить версию Python дефолтной (3.8), то из-за того, что wavelink требует Python >= 3.10, найдутся совершенно другие версии.\nА узнать об этом можно только изучив в pypi.org.\n\nРешение:\nВы можете изменить версию Python в конфигурационном файле, либо версии зависимостей в файле requirements.txt.\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n\n\nНе все файлы после заморозки проекта удалились:\nЕсли заморозить проект и сразу же пересобрать, то папка venv в Artifacts, отвечающая за окружение Python, повреждается,\nне успевая удалиться перед новой сборкой, из-за чего возникают ошибки вида:\n\nERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/.local'\n/app/venv/bin/python3: No module named pip.__main__; 'pip' is a package and cannot be directly executed\nError: [Errno 13] Permission denied: '/app/venv'\n\nРешить можно полной очисткой Artifacts. Для этого нужно перейти в «Настройки» и повторно заморозить проект, но на этот раз дать больше времени (около 20 секунд) для того, чтобы папка venv успевала удалиться и не вызывала конфликтов во время сборки.\nЕсли заморозка не помогла, но ранее этот проект успешно собирался, попробуйте развернуть приложение в новом проекте, и напишите об этом в support@amvera.ru\n\n\nВы случайно загрузили папку Venv (для Python)\nЕсли вы используете Python, папку Venv загружать не нужно.\nЗависимости следует устанавливать, прописывая их в файле requirements.txt\nВы можете составить его через pip freeze, но мы рекомендуем прописать их руками, так-как pip freeze дает много лишних зависимостей, что может приводить к конфликтам окружений.\n\n\n
# 7   \n\nНе найден файл (no such file or directory …)\n\nВозможные причины:\n\nВ конфигурации указан не тот основной файл, который у вас используется в коде проекта.\n\n\nПример:\nВ amvera.yml указан файл для запуска app.py, а в вашем проекте он называется bot.py.\nли вы опечатались и назвали файл bott.py, а не bot.py.\n\n\nФайл имеет другой путь. Как пример он находится в одной директории, а система или ваш код ищет его в другой.\n\n\nПример:\nВаш проект лежит в условной папке «project» (или как у вас она называется в проекте), в которой уже содержатся файлы app.py, amvera.yaml и т.д.\nПри этом вы в конфигурации просто указали файл запуска app.py. В данном случае система будет искать файл app.py на одном уровне с папкой project и, разумеется, данный файл не найдет. Можно либо изменить путь в конфигурации, либо вынести файлы в корень, убрав папку «project».\n\nКак работать с путями, можно ознакомиться по ссылке https://docs.amvera.ru/applications/storage.html\n\nФайл не загружен. Просмотреть список загруженных файлов можно в разделе «Репозиторий».\nНе установлено требуемое окружение.\n\n\nПример:\nВаш проект на python и вы устанавливаете зависимости с использованием файла requirements.txt. Убедитесь, что все зависимости прописаны. Некоторые зависимости, такие как SQLite прописывать не надо, они уже встроены в python и конфликтуют при их указании. Дополнительно не рекомендуем использовать pip freeze, так как он создает много лишних зависимостей. Дополнительно следует убедиться, что версия Python поддерживает указанные версии библиотек. Для этого можно изменить версию Python. Если вы используете Node.JS, убедитесь, что вы случайно не загрузили node_modules, вы не указали несуществующий параметр в секции build и вы не устанавливали пропуск сборки.\n\n\n\nРешение:\nВнимательно проверить соответствие проекта с файлом конфигурации, все пути и факт загрузки.\n\nПодсказка\nЕсли вы уверены, что все проверили и все верно, попробуйте удалить все файлы из папки Artifacts в интер...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \n\nспользуется другой часовой пояс (на серверах - UTC)\n\nВозможные причины:\nВ коде приложения не учтено, что на серверах Amvera время - UTC. Это -3 часа от Московского времени.\n\nВремя на сервере - UTC (-3 часа от Москвы)\n\n\n\nРешение:\nУчтите в коде приложения, что на серверах время UTC (-3 часа от МСК) и может не совпадать с временем в вашем регионе.\nзменить время на сервере нельзя, нужно учесть данный момент на стороне кода приложения.\n\n\n
# 9   \n\nОшибки при работе с git\n\n«Repository … not found»\n\nЕсли вы клонировали репозиторий, он мог стать основным. В таком случае следует выполнить просто команду git push (без main, master и т.д.)\nДополнительно проверьте корректность команды, что вы не перепутали - и _ и т.д.\nПроверьте, что вы пушите в нужный проект с актуального аккаунта.\nПопробуйте сделать push из другой консоли (GitHub Desktop как пример).\nПроверьте, привязали ли вы репозиторий ( git remote -v )\nПроверьте, с того ли аккаунта происходит авторизация. Так, если у Вас несколько аккаунтов в Amvera, Вы можете пытаться\nделать push/pull в другой аккаунт, где такого репозитория, естественно, нет и необходимо\nсбросить данные авторизации\n\n\n\n«faild to push some refs to …»\nНе удается загрузить некоторые ссылки\n\nВозможно, вы производили загрузку файлов/конфигурации через интерфейс до этого.\n\nВам нужно сделать git pull (либо git pull amvera master), чтобы синхронизировать проект с учётом тех изменений, что были внесены с другого устройства (из интерфейса).\n\n\nНет реакции на push\nСделали push, но ничего не происходит (сборка не начинается, логи пустые и т.д.). Вероятно, push не дошел до master ветки удаленного репозитория.\n\nПуш идет не в master, а в main\nЕсли основная ветка называется не master, а, например, main, при выполнении команды git push amvera master появится ошибка.\nВ таком случае выполните команду:\ngit push amvera имя_основной_ветки:master\n\n\nТак, например, если ваша основная ветка называется main, команда будет выглядеть следующим образом:\ngit push amvera main:master\n\n\nЧтобы узнать, какое название имеет основная ветка (в предположении, что вы на ней находитесь):\ngit branch --show-current\n\n\n\nНеверно выполняется обновление git (когда проект запущен и нужно обновить данные)\nЧастой ошибкой является неверная последовательность команд git (когда проект уже запущен и нужно его обновить).\nСимптомом является ответ команды git, когда Вы изменяли код:\n  Everything up-t...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \n\nПроблема с оплатой\nЕсли Вы из Белоруссии, Казахстана, Армении или другой страны, и используете карту банка выпущенную не в России, платеж может не проходить.\nНа данный момент поддерживается оплата иностранными картами Mastercard.\n\nВажно\nМинимальный платеж по иностранным Mastercard - 1000 руб.\n\nНаша платежная система обещает стабилизировать прием платежей по картам Visa/Mastercard, но повлиять на это мы не можем.\nВ таком случае рекомендуем воспользоваться одним из следующих способов.\n\nПопробовать использовать карту Mastercard.\nОплата через QIWI.\nОплата через UnionPay (да, мы понимаем, что скорее всего у вас нет этой карты).\nНапишите в support@amvera.ru мы найдем индивидуальное решение.\n\n\nВнимание\nЕсли вы из России и оплата не проходит - пишите в support@amvera.ru. Просим сразу указывать имя пользователя и проекта.\n\n\n

# %% [markdown]
# DataFrame ques_instr_data содержит список вопросов и название инструкций, в которой содержится ответ на заданный вопрос

# %%
ques_instr_data = pd.read_csv("ques_instr.csv",sep=';', names = ['instruction', 'question'])
ques_instr_data
# Out:
#      instruction  \
# 0         update
# 1         update
# 2         update
# 3         update
# 4         update
# ..           ...
# 158  data-saving
# 159  data-saving
# 160     UTC-time
# 161     UTC-time
# 162     UTC-time
#
#                                                                              question
# 0                                         писать git commit, но бот не останавливался
# 1                                                      коммить уже задеплоенного бота
# 2                                               проекты не получают обновление с гита
# 3    переодически приложение зависает в статусе сборки, хотя сервис досупен публично
# 4                                          проблема обновления проекта (бот в телеге)
# ..                                                                                ...
# 158                                             сохраняете в /data базу данных SQLite
# 159                          при перезапуске/пересборке проекта данные не сохраняются
# 160                                                                               UTC
# 161                                                    на серверах Amvera время - UTC
# 162        время UTC (-3 часа от МСК) и может не совпадать с временем в вашем регионе
#
# [163 rows x 2 columns]

# %% [markdown]
# # Визуализация данных

# %% [markdown]
# Из гистограммы ниже видно неравномерное распределение количества вопросов по инструкциям

# %%
instructions = ques_instr_data['instruction'].value_counts()
plt.xlabel('Инструкция')
plt.ylabel('Количество вопросов')
plt.barh(y=instructions.index, width=instructions.values)
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# # Предподготовка данных

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')

stop_words_en = set(stopwords.words('english'))
#lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words_ru = set(stopwords.words('russian'))
stop_words = stop_words_en.union(stop_words_ru).union(('(', ')', '«', '»', '-', '#', '@', ',', ', ', '.', ':','error', 'ошибка', 'ошибку', 'ошибки', 'ошибкой', 'помощь', 'помогать'))

# %%
#функция удаляет стоп-слова и приводит к нижнему регистру text
def preprocess(text):
    text = list(word_tokenize(text.lower()))
    text = list(word for word in text if word not in stop_words)
    return ' '.join(text)

# %%
instr_data['article_join'] = instr_data['row_article'].apply(preprocess)
instr_data
# Out:
#                   link  \
# 0       errors-in-logs
# 1               update
# 2          data-saving
# 3        502-503-error
# 4   infinite-build-run
# 5                tgbot
# 6             enverror
# 7       not-found-file
# 8             UTC-time
# 9          freq-errors
# 10            payments
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         row_article  \
# 0   \n\nОшибки в логах и их причины\nНа данной странице собраны самые основные и популярные ошибки, возникающие при деплое приложения различных окружений.\n\nОшибки, актуальные для всех окружений\nСамая распространенная ошибка связана с некорректным указанием пути к базе данных SQLite. Подробно о работе с SQLite здесь: SQLite\n\nRUNNING - FAILED - SUCCEEDED - DELETED в цикле лога приложения (не сборки)\nЕсли статусы в логе приложения (не лог сборки) ушли в подобный бесконечный цикл.\n\nПовысьте тариф до одного из старших. Скорее всего приложению не хватает ресурса, чтобы запуститься. Потом его можно  будет понизить.\nПроверьте, что вы загрузили не пустые файлы. Для этого скачайте код из раздела «Репозиторий» и посмотрите содержимое.\n\nВажно, статус DELETED не является ошибкой работы проекта. Это нормальный статус при сборке и запуске приложения.\n\n\nTerminated by other getupdates request (Телеграм бот)\nЭкземляр бота конфликтует с другим\nНужно:\n\nУбедиться, что выставлен только 1 инстанс. Телеграм боты в режиме опроса не поддерживают горизонтальное масштабирование\nУбедиться, что токен бота больше нигде не используется и бот нигде не запущен.\n\nПроще всего просто сбросить токен в @BotFather\n\n\nPermission denied - не все файлы после заморозки/пересборки проекта удалились/обновились:\nЕсли заморозить проект и сразу же пересобрать, то папка venv в Artifacts, отвечающая за окружение Python, повреждается,\nне успевая удалиться перед новой сборкой, из-за чего возникают ошибки вида:\n\nERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/.local'\n/app/venv/bin/python3: No module named pip.__main__; 'pip' is a package and cannot be directly executed\nError: [Errno 13] Permission denied: '/app/venv'\n\nРешить можно полной очисткой Artifacts. Для этого нужно перейти в «Настройки» и повторно заморозить проект, но на этот раз дать больше времени (около 3 минут) для того, чтобы папка venv успевала удалиться и не вызывала конфликтов во время...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \n\nНе получается обновить проект\nВозможные причины:\n\nНеверная последовательность команд git\nЧастой ошибкой является неверная последовательность команд git (когда проект уже запущен и нужно его обновить)\nСимптомом является ответ команды git, когда вы изменяли код и выполнили git push:\nEverything up-to-date\n\n\nВам поможет следующая последовательность команд:\ngit add .\ngit commit -m "Описание сделанных изменений"\ngit push amvera master\n\n\nНе забудьте про точку в первой команде - она нужна. При этом убедитесь, что файлы, содержащие конфиденциальную информацию (по типу токенов), такие как .env, находятся в .gitignore. Переменные окружения лучше всего указывать именно во вкладке «Переменные» проекта.\n\n\nСборка/развертывание перестала работать\nПроект ранее успешно обновлялся, но в этот раз сборка/развертывание не работает.\nРекомендуем заморозить приложение через интерфейс личного кабинета во вкладке «Настройки», подождать пару минут и повторить\npush/сборку. В ряде случаев данная ошибка может быть вызвана старыми артефактами и их удаление может помочь.\nЕсли ни один из способов выше не помогает, вы можете пересоздать проект с новым именем.\n\nВнимание\nЗаморзка проекта остановит все текущие инстансы приложения без возможности их запуска без пересборки.\n\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        \n\nНе сохраняются данные при перезапуске/пересборке приложения/базы данных\nЕсли при перезапуске/пересборке проекта ваши данные не сохраняются, убедитесь, что вы их сохраняете в каталог /data.\nДанная директория специально создана нами для того, чтобы при перезапусках проектов, пересборке и т.д. все ваши данные\nбыли сохранны и доступны.\nПомимо этого, данные хранимые в /data мы сохраняем в трёх экземплярах на разных узлах кластера, дополнительно делая\nрегулярные бэкапы, что снижает риск их безвозвратной потери.\nЕсли вам неудобно использовать каталог /data, обычно вы можете его изменить в файле amvera.yaml. Например:\n# часть amvera.yml\nrun:\n  persistenceMount: /var/myapp/data\n\n\n\nВажно\nПапка data в корне проекта и директория /data, это разные директории.\nПроверить, что сохранение идет в /data, можно зайдя в папку «data» на странице «Репозиторий».\n\nДля удобства тестирования, вы можете создать директорию /data на локальном компьютере.\nПри развертывании полностью с помощью amvera.yaml, мы не рекомендуем задавать значение run.persistenceMount равной\n/app или его подпапке: это может приводить к некорректному поведению.\nЕсли вы сохраняете в /data базу данных SQLite, ознакомьтесь с инструкцией.\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n
# 3   \n\n502/503 ошибка при статусе «Приложение запущено»\nЕсли развернув проект со статусом «Приложение запущено» вы наблюдаете 503 или 502 ошибку и нет логов, это связано с одной из нижеперечисленных причин.\n\nОшибка 502\nОшибка 502 в нашем случае чаще всего возникает в двух случаях:\n\nОт несоответствия портов, прописанных в коде или команде запуска и портов, прописанных в файле конфигурации (amvera.yaml).\nз-за того, что приложение работает на localhost, вместо 0.0.0.0.\n\nРазберем оба случая более подробно.\n\nПриложение слушает не тот порт\nПо умолчанию в Amvera Cloud открыт порт 80. При разработке веб приложения, вы указываете то, какой порт будет ваше приложение. Обычно это значение port в команде запуска приложения либо в значении параметра метода запуска приложения.\nНапример, если логика запуска вашего приложения в коде выглядит так (пример на Python, Flask):\nif __name__ == "__main__":\n    #...\n    app.run(host="0.0.0.0", port=5000, debug=True)\n\n\nТо в amvera.yml нужно указать в значение параметра containerPort порт 5000.\n# часть amvera.yaml\nrun:\n  containerPort: 5000\n\n\nВместо 5000 можно указать номер порта, который слушает ваше приложение по аналогии.\n\n\nHost не изменен на 0.0.0.0\nОбычно в тех же параметрах запуска приложения указывается адрес (host), на котором будет работать ваше приложение. Как правило, этот параметр несет название host, а его значение по умолчанию - localhost (127.0.0.1— 127.255.255.254).\nЕсли host оставлен в значении localhost(127.0.0.1— 127.255.255.254), а не 0.0.0.0 вы можете получить ошибку 502.\nЕсли это так: поменяйте значение хоста на 0.0.0.0. В таком случае приложение будет работать на всех интерфейсах, а не только на localhost, что и требуется для успешного запуска приложения.\nПример, как должен выглядеть запуск вашего приложения (Python, Flask):\napp.run(host='0.0.0.0', port=ваш порт)\n\n\nЕсли ничего из этого не помогло решить проблему, проверьте, что вы пересобираете проект, а не просто перезапускаете или ...
# 4   \n\nБесконечный запуск, сборка или отсутствие логов\n\nБесконечный запуск\nCопровождается статусом «сборка выполнена успешно, выполняется запуск».\n\nЕсли статус «Выполняется запуск» наблюдается более 5 минут, это свидетельствует об ошибке в конфигурационном файле или его отсутствии, либо о другой ошибке работы приложения.\n\nНеобходимо загрузить Лог приложения. В нем вы найдете лог с «error», который подскажет причину ошибки.\n\nЛибо вашему приложению необходимо использовать более высокий тариф (требуется больше ресурса для запуска). Мы рекомендуем при первой сборке выбрать один из старших тарифов и потом его изменить. После запуска вы сможете изменить тариф в Настройках на тот, при котором приложение работает и который устраивает вас по цене.\n\n\n\nБесконечная сборка\nСборка проектов в Amvera Cloud происходит дольше чем на локальной машине.\nСреднее время сборки составляет 5-20 минут. В редких случаях сборка может происходить до 30-60 минут.\n\nЕсли ваш проект находится в статусе «сборка» больше часа и отсутствуют логи - значит сборка закончилась с ошибкой и стоит убедиться в правильности конфигурационного файла.\n\nОзнакомьтесь с Логом сборки. В нем вы найдете лог с «error», который подскажет причину ошибки.\n\nЛибо вашему приложению необходимо использовать более высокий тариф (требуется больше ресурса для запуска). Мы рекомендуем при первой сборке выбрать один из старших тарифов и потом его изменить. После запуска вы сможете изменить тариф в Настройках на тот, при котором приложение работает и который устраивает вас по цене.\n\n\n\nПроект «завис» при сборке/запуске\nПри этом в интерфейсе не получается им управлять (неактивны кнопки пересборки/перезапуска)\nСимптоматикой данной проблемы является статус сборки/запуска более 30 минут и неактивные кнопки в интерфейсе.\nЭто вызвано либо тем, что ваш проект сложный и требует долгой сборки.\n\nПроверьте Лог сборки и Лог Приложения на наличие ошибок.\nПопробуйте немного подождать (20-30 минут). Некоторые проекты до...
# 5   \n\nНе работает телеграм-бот\nПроверьте Лог сборки и Лог приложения. С высокой вероятностью вы найдете там причину ошибки.\nНиже приведены частые ошибки при развертывании ботов.\n\nБот используется на 2 устройствах\nВо время запуска/перезапуска, инстанс может работать в двух экземплярах около секунды, что может вызывать такого плана ошибку.\nОшибка выглядит следующим образом:\naiogram.utils.exceptions.TerminatedByOtherGetUpdates: Terminated by other getupdates request; make sure that only one bot instance is running\n\n\nПопробуйте поставить delay 2-5 сек на создание объекта, это должно помочь.\n\nПример для бота на Python с использованием telebot\nПеред\nbot = telebot.TeleBot(token) # или подобной строкой\n\n\nПрописать\nimport time\ntime.sleep(5)\n\n\n\n\n\nНеверное название устанавливаемой библиотеки «телебота» в requirements.txt\nТелебот в requirements.txt должен называться pyTelegramBotAPI, а не telebot.\nПосле замены telebot на pyTelegramBotAPI необходимо заморозить проект, воспользовавшись соответсвующее кнопкой на вкладке\n«Настройки».  только после этого пересобирать приложение.\nЗаморозка необходима, чтобы гарантировано очистить кэш, в котором может сохраниться старая зависимость!\n\n\nНет логов\nЕсли статус приложения «Успешно запущено» и проект использует язык Python, то для отображения вывода команды print\nнадо выставить переменную окружения PYTHONUNBUFFERED в 1.\n\n\nВы случайно загрузили папку Venv (для Python)\nЕсли вы используете Python, папку Venv загружать не нужно.\nЗависимости следует устанавливать через requirements.txt\nВы можете составить его через pip freeze, но мы рекомендуем прописать их руками, так как pip freeze дает много лишних зависимостей, что может приводить к конфликтам окружений.\n\n\nЕсли статус проекта «Приложение запущено», но бот молчит\nЧаще всего это связано с тем, что приложение все-таки не успело запуститься и нужно подождать. Если ожидание не помогает, рекомендуется пересобрать проект или поднять тариф.\n\n\nСистема ...
# 6                                   \n\nОшибка venv в Python при сборке или запуске приложения\n\nНесоответствие версии библиотек версии окружения:\nПроблема с тем, что pip (если вы используете Python) находит не те версии библиотеки.\nК примеру: wavelink, если оставить версию Python дефолтной (3.8), то из-за того, что wavelink требует Python >= 3.10, найдутся совершенно другие версии.\nА узнать об этом можно только изучив в pypi.org.\n\nРешение:\nВы можете изменить версию Python в конфигурационном файле, либо версии зависимостей в файле requirements.txt.\n\nПодсказка\nЕсли не получается разобраться, пишите в поддержку support@amvera.ru. Просим сразу указывать имя пользователя и проекта. Мы постараемся помочь.\n\n\n\n\nНе все файлы после заморозки проекта удалились:\nЕсли заморозить проект и сразу же пересобрать, то папка venv в Artifacts, отвечающая за окружение Python, повреждается,\nне успевая удалиться перед новой сборкой, из-за чего возникают ошибки вида:\n\nERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/.local'\n/app/venv/bin/python3: No module named pip.__main__; 'pip' is a package and cannot be directly executed\nError: [Errno 13] Permission denied: '/app/venv'\n\nРешить можно полной очисткой Artifacts. Для этого нужно перейти в «Настройки» и повторно заморозить проект, но на этот раз дать больше времени (около 20 секунд) для того, чтобы папка venv успевала удалиться и не вызывала конфликтов во время сборки.\nЕсли заморозка не помогла, но ранее этот проект успешно собирался, попробуйте развернуть приложение в новом проекте, и напишите об этом в support@amvera.ru\n\n\nВы случайно загрузили папку Venv (для Python)\nЕсли вы используете Python, папку Venv загружать не нужно.\nЗависимости следует устанавливать, прописывая их в файле requirements.txt\nВы можете составить его через pip freeze, но мы рекомендуем прописать их руками, так-как pip freeze дает много лишних зависимостей, что может приводить к конфликтам окружений.\n\n\n
# 7   \n\nНе найден файл (no such file or directory …)\n\nВозможные причины:\n\nВ конфигурации указан не тот основной файл, который у вас используется в коде проекта.\n\n\nПример:\nВ amvera.yml указан файл для запуска app.py, а в вашем проекте он называется bot.py.\nли вы опечатались и назвали файл bott.py, а не bot.py.\n\n\nФайл имеет другой путь. Как пример он находится в одной директории, а система или ваш код ищет его в другой.\n\n\nПример:\nВаш проект лежит в условной папке «project» (или как у вас она называется в проекте), в которой уже содержатся файлы app.py, amvera.yaml и т.д.\nПри этом вы в конфигурации просто указали файл запуска app.py. В данном случае система будет искать файл app.py на одном уровне с папкой project и, разумеется, данный файл не найдет. Можно либо изменить путь в конфигурации, либо вынести файлы в корень, убрав папку «project».\n\nКак работать с путями, можно ознакомиться по ссылке https://docs.amvera.ru/applications/storage.html\n\nФайл не загружен. Просмотреть список загруженных файлов можно в разделе «Репозиторий».\nНе установлено требуемое окружение.\n\n\nПример:\nВаш проект на python и вы устанавливаете зависимости с использованием файла requirements.txt. Убедитесь, что все зависимости прописаны. Некоторые зависимости, такие как SQLite прописывать не надо, они уже встроены в python и конфликтуют при их указании. Дополнительно не рекомендуем использовать pip freeze, так как он создает много лишних зависимостей. Дополнительно следует убедиться, что версия Python поддерживает указанные версии библиотек. Для этого можно изменить версию Python. Если вы используете Node.JS, убедитесь, что вы случайно не загрузили node_modules, вы не указали несуществующий параметр в секции build и вы не устанавливали пропуск сборки.\n\n\n\nРешение:\nВнимательно проверить соответствие проекта с файлом конфигурации, все пути и факт загрузки.\n\nПодсказка\nЕсли вы уверены, что все проверили и все верно, попробуйте удалить все файлы из папки Artifacts в интер...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \n\nспользуется другой часовой пояс (на серверах - UTC)\n\nВозможные причины:\nВ коде приложения не учтено, что на серверах Amvera время - UTC. Это -3 часа от Московского времени.\n\nВремя на сервере - UTC (-3 часа от Москвы)\n\n\n\nРешение:\nУчтите в коде приложения, что на серверах время UTC (-3 часа от МСК) и может не совпадать с временем в вашем регионе.\nзменить время на сервере нельзя, нужно учесть данный момент на стороне кода приложения.\n\n\n
# 9   \n\nОшибки при работе с git\n\n«Repository … not found»\n\nЕсли вы клонировали репозиторий, он мог стать основным. В таком случае следует выполнить просто команду git push (без main, master и т.д.)\nДополнительно проверьте корректность команды, что вы не перепутали - и _ и т.д.\nПроверьте, что вы пушите в нужный проект с актуального аккаунта.\nПопробуйте сделать push из другой консоли (GitHub Desktop как пример).\nПроверьте, привязали ли вы репозиторий ( git remote -v )\nПроверьте, с того ли аккаунта происходит авторизация. Так, если у Вас несколько аккаунтов в Amvera, Вы можете пытаться\nделать push/pull в другой аккаунт, где такого репозитория, естественно, нет и необходимо\nсбросить данные авторизации\n\n\n\n«faild to push some refs to …»\nНе удается загрузить некоторые ссылки\n\nВозможно, вы производили загрузку файлов/конфигурации через интерфейс до этого.\n\nВам нужно сделать git pull (либо git pull amvera master), чтобы синхронизировать проект с учётом тех изменений, что были внесены с другого устройства (из интерфейса).\n\n\nНет реакции на push\nСделали push, но ничего не происходит (сборка не начинается, логи пустые и т.д.). Вероятно, push не дошел до master ветки удаленного репозитория.\n\nПуш идет не в master, а в main\nЕсли основная ветка называется не master, а, например, main, при выполнении команды git push amvera master появится ошибка.\nВ таком случае выполните команду:\ngit push amvera имя_основной_ветки:master\n\n\nТак, например, если ваша основная ветка называется main, команда будет выглядеть следующим образом:\ngit push amvera main:master\n\n\nЧтобы узнать, какое название имеет основная ветка (в предположении, что вы на ней находитесь):\ngit branch --show-current\n\n\n\nНеверно выполняется обновление git (когда проект запущен и нужно обновить данные)\nЧастой ошибкой является неверная последовательность команд git (когда проект уже запущен и нужно его обновить).\nСимптомом является ответ команды git, когда Вы изменяли код:\n  Everything up-t...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \n\nПроблема с оплатой\nЕсли Вы из Белоруссии, Казахстана, Армении или другой страны, и используете карту банка выпущенную не в России, платеж может не проходить.\nНа данный момент поддерживается оплата иностранными картами Mastercard.\n\nВажно\nМинимальный платеж по иностранным Mastercard - 1000 руб.\n\nНаша платежная система обещает стабилизировать прием платежей по картам Visa/Mastercard, но повлиять на это мы не можем.\nВ таком случае рекомендуем воспользоваться одним из следующих способов.\n\nПопробовать использовать карту Mastercard.\nОплата через QIWI.\nОплата через UnionPay (да, мы понимаем, что скорее всего у вас нет этой карты).\nНапишите в support@amvera.ru мы найдем индивидуальное решение.\n\n\nВнимание\nЕсли вы из России и оплата не проходит - пишите в support@amvera.ru. Просим сразу указывать имя пользователя и проекта.\n\n\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        article_join
# 0   логах причины данной странице собраны самые основные популярные возникающие деплое приложения различных окружений актуальные окружений самая распространенная связана некорректным указанием пути базе данных sqlite подробно работе sqlite sqlite running failed succeeded deleted цикле лога приложения сборки статусы логе приложения лог сборки ушли подобный бесконечный цикл повысьте тариф одного старших скорее приложению хватает ресурса запуститься понизить проверьте загрузили пустые файлы скачайте код раздела репозиторий посмотрите содержимое важно статус deleted является работы проекта это нормальный статус сборке запуске приложения terminated getupdates request телеграм бот экземляр бота конфликтует другим нужно убедиться выставлен 1 инстанс телеграм боты режиме опроса поддерживают горизонтальное масштабирование убедиться токен бота нигде используется бот нигде запущен проще просто сбросить токен botfather permission denied файлы заморозки/пересборки проекта удалились/обновились заморозить проект сразу пересобрать папка venv artifacts отвечающая окружение python повреждается успевая удалиться новой сборкой из-за возникают вида could install packages due oserror [ errno 13 ] permission denied '/.local ' /app/venv/bin/python3 module named pip.__main__ ; 'pip ' package directly executed [ errno 13 ] permission denied '/app/venv ' решить полной очисткой artifacts нужно перейти настройки повторно заморозить проект дать времени около 3 минут папка venv успевала удалиться вызывала конфликтов время сборки заморозка помогла ранее проект успешно собирался попробуйте развернуть приложение новом проекте напишите support amvera.ru python некоторые коды ошибок следствия могут относиться различным окружениям modulenotfounderror importerror modulenotfounderror module named ' ... ' importerror import name ' ... ' ' ... ' /app/ ... говорит импортируемая библиотека модуль пакет найден случае импортируется стороннаяя библиотека pip сверить название библиотеки pip сайте https //pypi.or...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      получается обновить проект возможные причины неверная последовательность команд git частой является неверная последовательность команд git проект запущен нужно обновить симптомом является ответ команды git изменяли код выполнили git push everything up-to-date поможет следующая последовательность команд git add git commit -m `` описание сделанных изменений '' git push amvera master забудьте точку первой команде нужна убедитесь файлы содержащие конфиденциальную информацию типу токенов такие .env находятся .gitignore переменные окружения указывать именно вкладке переменные проекта сборка/развертывание перестала работать проект ранее успешно обновлялся сборка/развертывание работает рекомендуем заморозить приложение интерфейс личного кабинета вкладке настройки подождать пару минут повторить push/сборку ряде случаев данная вызвана старыми артефактами удаление помочь способов выше помогает можете пересоздать проект новым именем внимание заморзка проекта остановит текущие инстансы приложения возможности запуска пересборки подсказка получается разобраться пишите поддержку support amvera.ru просим сразу указывать имя пользователя проекта постараемся помочь
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    сохраняются данные перезапуске/пересборке приложения/базы данных перезапуске/пересборке проекта ваши данные сохраняются убедитесь сохраняете каталог /data данная директория специально создана нами перезапусках проектов пересборке т.д ваши данные сохранны доступны помимо данные хранимые /data сохраняем трёх экземплярах разных узлах кластера дополнительно делая регулярные бэкапы снижает риск безвозвратной потери неудобно использовать каталог /data обычно можете изменить файле amvera.yaml например часть amvera.yml run persistencemount /var/myapp/data важно папка data корне проекта директория /data это разные директории проверить сохранение идет /data зайдя папку data странице репозиторий удобства тестирования можете создать директорию /data локальном компьютере развертывании полностью помощью amvera.yaml рекомендуем задавать значение run.persistencemount равной /app подпапке это приводить некорректному поведению сохраняете /data базу данных sqlite ознакомьтесь инструкцией подсказка получается разобраться пишите поддержку support amvera.ru просим сразу указывать имя пользователя проекта постараемся помочь
# 3   502/503 статусе приложение запущено развернув проект статусом приложение запущено наблюдаете 503 502 логов это связано одной нижеперечисленных причин 502 502 нашем случае чаще возникает двух случаях несоответствия портов прописанных коде команде запуска портов прописанных файле конфигурации amvera.yaml з-за приложение работает localhost вместо 0.0.0.0. разберем оба случая подробно приложение слушает порт умолчанию amvera cloud открыт порт 80. разработке веб приложения указываете порт ваше приложение обычно это значение port команде запуска приложения либо значении параметра метода запуска приложения например логика запуска вашего приложения коде выглядит пример python flask __name__ == `` __main__ '' ... app.run host= '' 0.0.0.0 '' port=5000 debug=true amvera.yml нужно указать значение параметра containerport порт 5000 часть amvera.yaml run containerport 5000 вместо 5000 указать номер порта который слушает ваше приложение аналогии host изменен 0.0.0.0 обычно тех параметрах запуска приложения указывается адрес host котором работать ваше приложение правило параметр несет название host значение умолчанию localhost 127.0.0.1— 127.255.255.254 host оставлен значении localhost 127.0.0.1— 127.255.255.254 0.0.0.0 можете получить 502. это поменяйте значение хоста 0.0.0.0. таком случае приложение работать интерфейсах localhost требуется успешного запуска приложения пример должен выглядеть запуск вашего приложения python flask app.run host= ' 0.0.0.0 ' port=ваш порт помогло решить проблему проверьте пересобираете проект просто перезапускаете попробуйте повысить тариф 503 503 говорит сервис недоступен правило явные причины следующие приложение фактически запущено запуститься связи какой-либо сервис перегружен нужно повысить тариф первом случае необходимо проверить лог приложения скорее втором рекомендуется поднять тариф рекомендация попробуйте запустить проект одном старших тарифов успешного запуска измените тариф подходящий разделе настройки выбран неподходящий тариф ногда ...
# 4   бесконечный запуск сборка отсутствие логов бесконечный запуск cопровождается статусом сборка выполнена успешно выполняется запуск статус выполняется запуск наблюдается 5 минут это свидетельствует ошибке конфигурационном файле отсутствии либо ошибке работы приложения необходимо загрузить лог приложения нем найдете лог который подскажет причину либо вашему приложению необходимо использовать высокий тариф требуется ресурса запуска рекомендуем первой сборке выбрать старших тарифов изменить запуска сможете изменить тариф настройках котором приложение работает который устраивает цене бесконечная сборка сборка проектов amvera cloud происходит дольше локальной машине среднее время сборки составляет 5-20 минут редких случаях сборка происходить 30-60 минут ваш проект находится статусе сборка часа отсутствуют логи значит сборка закончилась стоит убедиться правильности конфигурационного файла ознакомьтесь логом сборки нем найдете лог который подскажет причину либо вашему приложению необходимо использовать высокий тариф требуется ресурса запуска рекомендуем первой сборке выбрать старших тарифов изменить запуска сможете изменить тариф настройках котором приложение работает который устраивает цене проект завис сборке/запуске интерфейсе получается управлять неактивны кнопки пересборки/перезапуска симптоматикой данной проблемы является статус сборки/запуска 30 минут неактивные кнопки интерфейсе это вызвано либо ваш проект сложный требует долгой сборки проверьте лог сборки лог приложения наличие ошибок попробуйте немного подождать 20-30 минут некоторые проекты долго собираются/запускаются дополнительные действия просто приведут тому процесс начнется заново произошло попробуйте запустить процесс сборки заново воспользовавшись кнопкой собрать вкладке конфигурация предварительно удалить файлы папки artifacts используете dockerfile amvera.yaml вместо прошлого действия требуется внести формальные изменения репозиторий запушить amvera попробуйте повысить тариф возможно вашему приложени...
# 5                                                                                                                                                                            работает телеграм-бот проверьте лог сборки лог приложения высокой вероятностью найдете причину ниже приведены частые развертывании ботов бот используется 2 устройствах время запуска/перезапуска инстанс работать двух экземплярах около секунды вызывать такого плана выглядит следующим образом aiogram.utils.exceptions.terminatedbyothergetupdates terminated getupdates request ; make sure one bot instance running попробуйте поставить delay 2-5 сек создание объекта это должно помочь пример бота python использованием telebot bot = telebot.telebot token подобной строкой прописать import time time.sleep 5 неверное название устанавливаемой библиотеки телебота requirements.txt телебот requirements.txt должен называться pytelegrambotapi telebot замены telebot pytelegrambotapi необходимо заморозить проект воспользовавшись соответсвующее кнопкой вкладке настройки пересобирать приложение заморозка необходима гарантировано очистить кэш котором сохраниться старая зависимость ! логов статус приложения успешно запущено проект использует язык python отображения вывода команды print выставить переменную окружения pythonunbuffered 1. случайно загрузили папку venv python используете python папку venv загружать нужно зависимости следует устанавливать requirements.txt можете составить pip freeze рекомендуем прописать руками pip freeze дает лишних зависимостей приводить конфликтам окружений статус проекта приложение запущено бот молчит чаще это связано приложение все-таки успело запуститься нужно подождать ожидание помогает рекомендуется пересобрать проект поднять тариф система найти файл file directory ознакомьтесь инструкцией несоответствие версий python зависимостей ознакомьтесь инструкцией подсказка получается разобраться пишите поддержку support amvera.ru просим сразу указывать имя пользователя проекта постараемся помочь
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          venv python сборке запуске приложения несоответствие версии библиотек версии окружения проблема pip используете python находит те версии библиотеки примеру wavelink оставить версию python дефолтной 3.8 из-за wavelink требует python > = 3.10 найдутся совершенно другие версии узнать изучив pypi.org решение можете изменить версию python конфигурационном файле либо версии зависимостей файле requirements.txt подсказка получается разобраться пишите поддержку support amvera.ru просим сразу указывать имя пользователя проекта постараемся помочь файлы заморозки проекта удалились заморозить проект сразу пересобрать папка venv artifacts отвечающая окружение python повреждается успевая удалиться новой сборкой из-за возникают вида could install packages due oserror [ errno 13 ] permission denied '/.local ' /app/venv/bin/python3 module named pip.__main__ ; 'pip ' package directly executed [ errno 13 ] permission denied '/app/venv ' решить полной очисткой artifacts нужно перейти настройки повторно заморозить проект дать времени около 20 секунд папка venv успевала удалиться вызывала конфликтов время сборки заморозка помогла ранее проект успешно собирался попробуйте развернуть приложение новом проекте напишите support amvera.ru случайно загрузили папку venv python используете python папку venv загружать нужно зависимости следует устанавливать прописывая файле requirements.txt можете составить pip freeze рекомендуем прописать руками так-как pip freeze дает лишних зависимостей приводить конфликтам окружений
# 7                                                                                                                                                                                                                                                                                              найден файл file directory … возможные причины конфигурации указан основной файл который используется коде проекта пример amvera.yml указан файл запуска app.py вашем проекте называется bot.py опечатались назвали файл bott.py bot.py файл имеет путь пример находится одной директории система ваш код ищет пример ваш проект лежит условной папке project называется проекте которой содержатся файлы app.py amvera.yaml т.д конфигурации просто указали файл запуска app.py данном случае система искать файл app.py одном уровне папкой project разумеется данный файл найдет либо изменить путь конфигурации либо вынести файлы корень убрав папку project работать путями ознакомиться ссылке https //docs.amvera.ru/applications/storage.html файл загружен просмотреть список загруженных файлов разделе репозиторий установлено требуемое окружение пример ваш проект python устанавливаете зависимости использованием файла requirements.txt убедитесь зависимости прописаны некоторые зависимости такие sqlite прописывать встроены python конфликтуют указании дополнительно рекомендуем использовать pip freeze создает лишних зависимостей дополнительно следует убедиться версия python поддерживает указанные версии библиотек изменить версию python используете node.js убедитесь случайно загрузили node_modules указали несуществующий параметр секции build устанавливали пропуск сборки решение внимательно проверить соответствие проекта файлом конфигурации пути факт загрузки подсказка уверены проверили верно попробуйте удалить файлы папки artifacts интерфейсе лк подождать 30 секунд пересобрать приложение подсказка получается разобраться пишите поддержку support amvera.ru просим сразу указывать имя пользователя проекта постараемся помочь
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 спользуется часовой пояс серверах utc возможные причины коде приложения учтено серверах amvera время utc это -3 часа московского времени время сервере utc -3 часа москвы решение учтите коде приложения серверах время utc -3 часа мск совпадать временем вашем регионе зменить время сервере нужно учесть данный момент стороне кода приложения
# 9   работе git repository … found клонировали репозиторий мог стать основным таком случае следует выполнить просто команду git push main master т.д дополнительно проверьте корректность команды перепутали _ т.д проверьте пушите нужный проект актуального аккаунта попробуйте сделать push консоли github desktop пример проверьте привязали репозиторий git remote -v проверьте аккаунта происходит авторизация несколько аккаунтов amvera можете пытаться делать push/pull аккаунт такого репозитория естественно необходимо сбросить данные авторизации faild push refs … удается загрузить некоторые ссылки возможно производили загрузку файлов/конфигурации интерфейс нужно сделать git pull либо git pull amvera master синхронизировать проект учётом тех изменений внесены другого устройства интерфейса реакции push сделали push происходит сборка начинается логи пустые т.д. вероятно push дошел master ветки удаленного репозитория пуш идет master main основная ветка называется master например main выполнении команды git push amvera master появится таком случае выполните команду git push amvera имя_основной_ветки master например ваша основная ветка называется main команда выглядеть следующим образом git push amvera main master узнать какое название имеет основная ветка предположении находитесь git branch -- show-current неверно выполняется обновление git проект запущен нужно обновить данные частой является неверная последовательность команд git проект запущен нужно обновить симптомом является ответ команды git изменяли код everything up-to-date поможет следующая последовательность команд git add добавляем сделанные изменения данной папке список проиндексированных git commit -m `` описание сделанных изменений '' git push amvera master забудьте точку первой команде нужна требуется добавить файлы индекс требуется добавить гит некоторые файлы стоит отдельно выполнить git add < file_name > каждого исключить ненужные файлы индексации путем написания .gitignore файла спользуются старые авторизационные...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            проблема оплатой белоруссии казахстана армении страны используете карту банка выпущенную россии платеж проходить данный момент поддерживается оплата иностранными картами mastercard важно минимальный платеж иностранным mastercard 1000 руб наша платежная система обещает стабилизировать прием платежей картам visa/mastercard повлиять это можем таком случае рекомендуем воспользоваться одним следующих способов попробовать использовать карту mastercard оплата qiwi оплата unionpay понимаем скорее карты напишите support amvera.ru найдем индивидуальное решение внимание россии оплата проходит пишите support amvera.ru просим сразу указывать имя пользователя проекта

# %%
ques_instr_data['question_join'] = ques_instr_data['question'].apply(preprocess)
ques_instr_data
# Out:
#      instruction  \
# 0         update
# 1         update
# 2         update
# 3         update
# 4         update
# ..           ...
# 158  data-saving
# 159  data-saving
# 160     UTC-time
# 161     UTC-time
# 162     UTC-time
#
#                                                                              question  \
# 0                                         писать git commit, но бот не останавливался
# 1                                                      коммить уже задеплоенного бота
# 2                                               проекты не получают обновление с гита
# 3    переодически приложение зависает в статусе сборки, хотя сервис досупен публично
# 4                                          проблема обновления проекта (бот в телеге)
# ..                                                                                ...
# 158                                             сохраняете в /data базу данных SQLite
# 159                          при перезапуске/пересборке проекта данные не сохраняются
# 160                                                                               UTC
# 161                                                    на серверах Amvera время - UTC
# 162        время UTC (-3 часа от МСК) и может не совпадать с временем в вашем регионе
#
#                                                                     question_join
# 0                                            писать git commit бот останавливался
# 1                                                      коммить задеплоенного бота
# 2                                                проекты получают обновление гита
# 3    переодически приложение зависает статусе сборки хотя сервис досупен публично
# 4                                          проблема обновления проекта бот телеге
# ..                                                                            ...
# 158                                           сохраняете /data базу данных sqlite
# 159                             перезапуске/пересборке проекта данные сохраняются
# 160                                                                           utc
# 161                                                     серверах amvera время utc
# 162                        время utc -3 часа мск совпадать временем вашем регионе
#
# [163 rows x 3 columns]

# %%
# количество наиболее подходящих инструкций к вопросу, полученных исследуемыми методами
K = 2

# %%
#функция подсчета адаптированной метрики качества ранжирования
def eval_mapK(row, col):
    indx = K
    for i in range(0, K):
        if row['instruction'] == row[col][i]:
            indx = i
            break
    return (K-indx)/K

# %% [markdown]
# # Векторные представления текстов инструкций и вопросов с TfIdf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import pairwise_distances
Tfidf_vectorizer = TfidfVectorizer()

# %%
tf_idf_instr = Tfidf_vectorizer.fit_transform(instr_data['article_join'])

# %%
tf_idf_instr.shape
# Out:
# (11, 1182)

# %%
tf_idf_ques = Tfidf_vectorizer.transform(ques_instr_data['question_join'])

# %%
tf_idf_ques.shape
# Out:
# (163, 1182)

# %% [markdown]
# Манхеттенское расстояние между векторами TfIdf вопросов и инструкций

# %%
manhattan_dist = pairwise_distances(tf_idf_ques, tf_idf_instr, metric='manhattan' )

# %% [markdown]
# Косинусное расстояние между векторами TfIdf вопросов и инструкций

# %%
cosine_dist = pairwise_distances(tf_idf_ques, tf_idf_instr, metric='cosine' )

# %%
mapK_cols = [] #список c названиями столбцов, содержащих оценки метрики качества ранжирования исследованных методов

# функция создает 2 столбца в DataFrame df: 1. "K" рекоммендованных инструкций; 2. оценку метрики качества
def create_pred_mapK_cols(df, pred_model, index, col_postfix, K, inverse = False):
  if inverse:
    tmp_list = [list(np.argsort(pred_model[i]))[::-1][:K] for i in range(pred_model.shape[0])]
  else:
    tmp_list = [list(np.argsort(pred_model[i]))[:K] for i in range(pred_model.shape[0])]
  df['pred_'+ col_postfix] = pd.Series(tmp_list, index = index) \
   .apply(lambda indx: list(instr_data.iloc[indx,0]))
  df['map@K_' + col_postfix] = df.apply(eval_mapK, axis=1, args = ('pred_' + col_postfix,))
  mapK_cols.append('map@K_' + col_postfix)

# %% [markdown]
# Столбец ques_instr_data.pred_tfidf_manhattan - "K" ближайших к вопросу инструкций, полученных оценкой манхеттенского расстояния на векторах TfIdf; ques_instr_data.map@K_tfidf_manhattan - оценка качества рекоммендации

# %%
create_pred_mapK_cols(ques_instr_data, manhattan_dist, ques_instr_data.index, 'tfidf_manhattan', K)

# %% [markdown]
# Столбец ques_instr_data.pred_tfidf_cosine - "K" ближайших к вопросу инструкций, полученных оценкой косинусного расстояния на векторах TfIdf; ques_instr_data.map@K_tfidf_cosine - оценка качества рекоммендации

# %%
create_pred_mapK_cols(ques_instr_data, cosine_dist, ques_instr_data.index, 'tfidf_cosine', K)

# %%
ques_instr_data
# Out:
#      instruction  \
# 0         update
# 1         update
# 2         update
# 3         update
# 4         update
# ..           ...
# 158  data-saving
# 159  data-saving
# 160     UTC-time
# 161     UTC-time
# 162     UTC-time
#
#                                                                              question  \
# 0                                         писать git commit, но бот не останавливался
# 1                                                      коммить уже задеплоенного бота
# 2                                               проекты не получают обновление с гита
# 3    переодически приложение зависает в статусе сборки, хотя сервис досупен публично
# 4                                          проблема обновления проекта (бот в телеге)
# ..                                                                                ...
# 158                                             сохраняете в /data базу данных SQLite
# 159                          при перезапуске/пересборке проекта данные не сохраняются
# 160                                                                               UTC
# 161                                                    на серверах Amvera время - UTC
# 162        время UTC (-3 часа от МСК) и может не совпадать с временем в вашем регионе
#
#                                                                     question_join  \
# 0                                            писать git commit бот останавливался
# 1                                                      коммить задеплоенного бота
# 2                                                проекты получают обновление гита
# 3    переодически приложение зависает статусе сборки хотя сервис досупен публично
# 4                                          проблема обновления проекта бот телеге
# ..                                                                            ...
# 158                                           сохраняете /data базу данных sqlite
# 159                             перезапуске/пересборке проекта данные сохраняются
# 160                                                                           utc
# 161                                                     серверах amvera время utc
# 162                        время utc -3 часа мск совпадать временем вашем регионе
#
#      instruction_num     pred_tfidf_manhattan  map@K_tfidf_manhattan  \
# 0                  1     [UTC-time, payments]                    0.0
# 1                  1     [UTC-time, payments]                    0.0
# 2                  1     [UTC-time, payments]                    0.0
# 3                  1     [UTC-time, payments]                    0.0
# 4                  1     [UTC-time, payments]                    0.0
# ..               ...                      ...                    ...
# 158                2  [UTC-time, data-saving]                    0.5
# 159                2  [UTC-time, data-saving]                    0.5
# 160                8     [UTC-time, payments]                    1.0
# 161                8     [UTC-time, payments]                    1.0
# 162                8     [UTC-time, payments]                    1.0
#
#                        pred_tfidf_cosine  map@K_tfidf_cosine
# 0                  [freq-errors, update]                 0.5
# 1                [tgbot, errors-in-logs]                 0.0
# 2      [infinite-build-run, freq-errors]                 0.0
# 3    [502-503-error, infinite-build-run]                 0.0
# 4                      [tgbot, payments]                 0.0
# ..                                   ...                 ...
# 158        [data-saving, errors-in-logs]                 1.0
# 159           [data-saving, freq-errors]                 1.0
# 160           [UTC-time, errors-in-logs]                 1.0
# 161            [UTC-time, 502-503-error]                 1.0
# 162           [UTC-time, not-found-file]                 1.0
#
# [163 rows x 8 columns]

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой манхеттенского расстояния на векторах TfIdf

# %%
ques_instr_data['map@K_tfidf_manhattan'].mean()
# Out:
# np.float64(0.05521472392638037)

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой косинусного расстояния на векторах TfIdf

# %%
ques_instr_data['map@K_tfidf_cosine'].mean()
# Out:
# np.float64(0.647239263803681)

# %% [markdown]
# Из приведенных выше оценок видно, что качество рекомендаций при применении TfIdf векторов значительно лучше при использование косинусного расстояния.

# %% [markdown]
# # Векторные представления текстов инструкций и вопросов с Bert

# %% [markdown]
# Нейронная сеть Bert принимает на вход последовательности длиной не больше 512 токенов. Проверим длины текстов инструкций.

# %%
instr_data['article_join'].apply(len)
# Out:
# 0     5207
# 1     1164
# 2     1118
# 3     3086
# 4     3272
# 5     1830
# 6     1512
# 7     1716
# 8      337
# 9     3533
# 10     661
# Name: article_join, dtype: int64

# %%
max_len = 0

# %%
#функция разбивает текст на части, содержащие не более 512 токенов
def get_chunks(row):
    global max_len
    local = row.strip('\n\n').split('\n\n')
    local = [local[i] for i in range(len(local)) if i not in [i for i in range(len(local)) if len(local[i]) == 0]]
    for i,chunk in enumerate(local):
        if len(chunk) > 512:
            num_subchunks = len(chunk)//512 + 1
            start_pos = len(chunk)//num_subchunks
            sep_pos = chunk[:start_pos].rfind('\n')
            if sep_pos == -1:
                sep_pos = chunk[:start_pos].rfind('.')
                if sep_pos == -1:
                    sep_pos = chunk[:start_pos].rfind(' ')
            local.append(chunk[(sep_pos+1):])
            local[i] = chunk[:(sep_pos)]
        local[i] = preprocess(local[i])
        if max_len < len(local[i]):
          max_len = len(local[i])
    return local

# %%
instr_data['article_chunks'] = instr_data['row_article'].apply(get_chunks)

# %%
# функция max пуллинга на векторами
def max_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    max_embeddings = torch.max(token_embeddings * input_mask_expanded, 1).values
    return max_embeddings

# %%
# функция mean пуллинга на векторами
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

# %% [markdown]
# Скачиваем токенизатор и предобученную модель BERT (для руссского языка)

# %%
tokenizer = AutoTokenizer.from_pretrained("ai-forever/sbert_large_nlu_ru")
model = AutoModel.from_pretrained("ai-forever/sbert_large_nlu_ru")

# функция возвращает эмбеддинги sentences, полученные с помощью BERT
def get_bert_vectors(sentences, func):
    encoded_input = tokenizer(sentences, padding=True, truncation=True, max_length=max_len, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**encoded_input)
    sentence_embeddings = func(model_output, encoded_input['attention_mask'])
    return sentence_embeddings
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/863 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]

# %%
pool_func = mean_pooling

# %% [markdown]
# Вектора BERT для инструкций, используя mean pooling

# %%
instr_mean_bert_vectors = instr_data['article_chunks'].apply(get_bert_vectors, args = (pool_func,))

# %% [markdown]
# Вектора BERT для вопросов, используя mean pooling

# %%
ques_mean_bert_vectors = ques_instr_data['question_join'].apply(get_bert_vectors, args = (pool_func,))

# %%
# функция возвращает "K" минимальных упорядоченных расстояний между эмбеддингами текущего вопроса и эмбеддингами инструкций
def get_dist(row, instr_bert_vectors, dist):
  bert_dist = []
  for i in range(len(instr_bert_vectors)):
    bert_dist.append(np.min(pairwise_distances(row, instr_bert_vectors[i].numpy(), metric=dist)[0]))
  return list(np.argsort(bert_dist))[:K]

# %% [markdown]
# Столбец ques_instr_data.pred_mean_bert_manhattan - "K" ближайших к вопросу инструкций, полученных оценкой манхеттенского расстояния на векторах BERT с mean pooling; ques_instr_data.map@K_mean_bert_manhattan - оценка качества рекоммендации

# %%
ques_instr_data['pred_mean_bert_manhattan'] = ques_mean_bert_vectors.apply(get_dist, args = (instr_mean_bert_vectors, 'manhattan',)).apply(lambda indx: list(instr_data.iloc[indx,0]))
ques_instr_data['map@K_mean_bert_manhattan'] = ques_instr_data.apply(eval_mapK, axis=1, args = ('pred_mean_bert_manhattan',))
mapK_cols.append('map@K_mean_bert_manhattan')

# %% [markdown]
# Столбец ques_instr_data.pred_mean_bert_cosine - "K" ближайших к вопросу инструкций, полученных оценкой косинусного расстояния на векторах BERT с mean pooling; ques_instr_data.map@K_mean_bert_cosine - оценка качества рекоммендации

# %%
ques_instr_data['pred_mean_bert_cosine'] = ques_mean_bert_vectors.apply(get_dist, args = (instr_mean_bert_vectors, 'cosine',)).apply(lambda indx: list(instr_data.iloc[indx,0]))
ques_instr_data['map@K_mean_bert_cosine'] = ques_instr_data.apply(eval_mapK, axis=1, args = ('pred_mean_bert_cosine',))
mapK_cols.append('map@K_mean_bert_cosine')

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой манхеттенского расстояния на векторах Bert с mean pooling

# %%
ques_instr_data['map@K_mean_bert_manhattan'].mean()
# Out:
# np.float64(0.3067484662576687)

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой косинусного расстояния на векторах Bert с mean pooling

# %%
ques_instr_data['map@K_mean_bert_cosine'].mean()
# Out:
# np.float64(0.32515337423312884)

# %% [markdown]
# Из приведенных выше оценок видно, что качество рекомендаций при применении Bert c mean pooling векторов немного лучше при использование косинусного расстояния нежели манхеттенского. Однако оценка косинусных расстояний на эмбеддингах Bert в два раза уступает аналогичной оценки на TfIdf.

# %%
pool_func = max_pooling

# %% [markdown]
# Вектора BERT для инструкций, используя max pooling

# %%
instr_max_bert_vectors = instr_data['article_chunks'].apply(get_bert_vectors, args = (pool_func,))

# %% [markdown]
# Вектора BERT для вопросов, используя max pooling

# %%
ques_max_bert_vectors = ques_instr_data['question_join'].apply(get_bert_vectors, args = (pool_func,))

# %% [markdown]
# Столбец ques_instr_data.pred_max_bert_manhattan - "K" ближайших к вопросу инструкций, полученных оценкой манхеттенского расстояния на векторах BERT с max pooling; ques_instr_data.map@K_max_bert_manhattan - оценка качества рекоммендации

# %%
ques_instr_data['pred_max_bert_manhattan'] = ques_max_bert_vectors.apply(get_dist, args = (instr_max_bert_vectors, 'manhattan',)).apply(lambda indx: list(instr_data.iloc[indx,0]))
ques_instr_data['map@K_max_bert_manhattan'] = ques_instr_data.apply(eval_mapK, axis=1, args = ('pred_max_bert_manhattan',))
mapK_cols.append('map@K_max_bert_manhattan')

# %% [markdown]
# Столбец ques_instr_data.pred_max_bert_cosine - "K" ближайших к вопросу инструкций, полученных оценкой косинусного расстояния на векторах BERT с max pooling; ques_instr_data.map@K_max_bert_cosine - оценка качества рекоммендации

# %%
ques_instr_data['pred_max_bert_cosine'] = ques_max_bert_vectors.apply(get_dist, args = (instr_max_bert_vectors, 'cosine',)).apply(lambda indx: list(instr_data.iloc[indx,0]))
ques_instr_data['map@K_max_bert_cosine'] = ques_instr_data.apply(eval_mapK, axis=1, args = ('pred_max_bert_cosine',))
mapK_cols.append('map@K_max_bert_cosine')

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой манхеттенского расстояния на векторах Bert с max pooling

# %%
ques_instr_data['map@K_max_bert_manhattan'].mean()
# Out:
# np.float64(0.29141104294478526)

# %% [markdown]
# Средняя оценка качества рекоммендаций инструкций, полученных оценкой косинусного расстояния на векторах Bert с max pooling

# %%
ques_instr_data['map@K_max_bert_cosine'].mean()
# Out:
# np.float64(0.3098159509202454)

# %% [markdown]
# Из приведенных выше оценок видно, что качество рекомендаций при применении Bert c max pooling векторов совсем немного лучше при использование косинусного расстояния нежели манхеттенского. Однако оценка косинусных расстояний на эмбеддингах Bert немногим больше чем в два раза уступает аналогичной оценки на TfIdf.

# %% [markdown]
# # XGBoost для классификации векторов TfIdf вопросов

# %% [markdown]
# Создадим новый столбец instruction_num в ques_instr_data - содержит индекс инструкции из instr_data, необходимый для multiclass классификации.

# %%
ques_instr_data['instruction_num'] = ques_instr_data['instruction'].apply(lambda row: instr_data[instr_data['link'] == row].index.values.tolist()[0])
ques_instr_data['instruction_num']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 158    2
# 159    2
# 160    8
# 161    8
# 162    8
# Name: instruction_num, Length: 163, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tf_idf_ques, ques_instr_data['instruction_num'], test_size=0.15, random_state = 123)

# %% [markdown]
# Так как обучающий набор данных мал, необходимо проследить, чтобы в train наборе были представлены все классы таргета.

# %%
y_train.value_counts()
# Out:
# instruction_num
# 3     31
# 9     23
# 6     21
# 5     14
# 4     10
# 7      8
# 2      8
# 1      7
# 0      7
# 10     6
# 8      3
# Name: count, dtype: int64

# %%
import xgboost as xgb
from sklearn.metrics import log_loss
from xgboost.sklearn import XGBClassifier

# %%
model_xgb = XGBClassifier(learning_rate=0.01,
                          n_estimators=200,
                          objective= 'multi:softprob',
                          nthread=-1,
                          seed=27)

# %% [markdown]
# Подберем гиперпараметры с помощью GridSearchCV.

# %%
from sklearn.model_selection import GridSearchCV

param_test = {
    'max_depth':range(2,7,2),
    'min_child_weight':range(1,6,2)
}

gsearch = GridSearchCV(estimator=model_xgb,
                        param_grid=param_test,
                        scoring='roc_auc_ovo',
                        n_jobs=-1,
                        cv=3)

gsearch.fit(X_train,y_train)

gsearch.best_params_, gsearch.best_score_
# Out:
# ({'max_depth': 4, 'min_child_weight': 1}, np.float64(0.6801499331596735))

# %% [markdown]
# Используем полученные параметры.

# %%
model_xgb = XGBClassifier(learning_rate=0.01,
                          n_estimators=200,
                          objective= 'multi:softprob',
                          max_depth = 4,
                          min_child_weight = 1,
                          nthread=-1,
                          seed=27)

# %%
model_xgb.fit(X_train,y_train)
y_pred_train_XGB_tfidf = model_xgb.predict_proba(X_train)
y_pred_test_XGB_tfidf = model_xgb.predict_proba(X_test)

# %% [markdown]
# Кросс-энтропия на train

# %%
output = log_loss(y_train, y_pred = y_pred_train_XGB_tfidf, labels = range(0,11))
output
# Out:
# 1.5648097662430835

# %% [markdown]
# Кросс-энтропия на test

# %%
output = log_loss(y_test, y_pred = y_pred_test_XGB_tfidf, labels = range(0,11))
output
# Out:
# 1.727452229529076

# %% [markdown]
# RocAuc метрика на train

# %%
roc_auc_score(y_train, y_pred_train_XGB_tfidf, multi_class='ovo')
# Out:
# np.float64(0.826396967734563)

# %% [markdown]
# RocAuc метрика на test

# %%
roc_auc_score(y_test, y_pred_test_XGB_tfidf, labels = range(0,11), multi_class='ovo')
# Out:
# np.float64(0.6816716269841269)

# %% [markdown]
# # XGBoost для классификации векторов Bert вопросов

# %%
def convert_to_list(row):
  return row.squeeze().tolist()

# %%
ques_mean_bert_vectors = ques_mean_bert_vectors.apply(convert_to_list)

# %%
ques_mean_bert_vectors_list = ques_mean_bert_vectors.tolist()

# %% [markdown]
# Разбиение  на test и train аналогичное, что и для векторов TfIdf из предыдущего эксперимента

# %%
X_train, X_test, y_train, y_test = train_test_split(ques_mean_bert_vectors_list, ques_instr_data['instruction_num'], test_size=0.15, random_state = 123)

# %%
y_train.value_counts()
# Out:
# instruction_num
# 3     31
# 9     23
# 6     21
# 5     14
# 4     10
# 7      8
# 2      8
# 1      7
# 0      7
# 10     6
# 8      3
# Name: count, dtype: int64

# %%
model_xgb = XGBClassifier(learning_rate=0.01,
                          n_estimators=150,
                          objective= 'multi:softprob',
                          nthread=-1,
                          seed=27)

# %%
gsearch = GridSearchCV(estimator=model_xgb,
                        param_grid=param_test,
                        scoring='roc_auc_ovo',
                        n_jobs=-1,
                        cv=3)

gsearch.fit(X_train,y_train)

gsearch.best_params_, gsearch.best_score_
# Out:
# ({'max_depth': 4, 'min_child_weight': 5}, np.float64(0.7416417225751641))

# %% [markdown]
# Используем полученные параметры.

# %%
model_xgb = XGBClassifier(learning_rate=0.01,
                          n_estimators=150,
                          objective= 'multi:softprob',
                          max_depth = 4,
                          min_child_weight = 5,
                          nthread=-1,
                          seed=27)

# %%
model_xgb.fit(X_train,y_train)
y_pred_train_XGB_bert = model_xgb.predict_proba(X_train)
y_pred_test_XGB_bert = model_xgb.predict_proba(X_test)

# %% [markdown]
# Кросс-энтропия на train

# %%
output = log_loss(y_train, y_pred = y_pred_train_XGB_bert, labels = range(0,11))
output
# Out:
# 1.23367883523843

# %% [markdown]
# Кросс-энтропия на test

# %%
output = log_loss(y_test, y_pred = y_pred_test_XGB_bert, labels = range(0,11))
output
# Out:
# 1.9342849937432396

# %% [markdown]
# RocAuc метрика на train

# %%
roc_auc_score(y_train, y_pred_train_XGB_bert, multi_class='ovo')
# Out:
# np.float64(0.9968365785686963)

# %% [markdown]
# RocAuc метрика на test

# %%
roc_auc_score(y_test, y_pred_test_XGB_bert, labels = range(0,11), multi_class='ovo')
# Out:
# np.float64(0.630766369047619)

# %% [markdown]
# Из приведенных выше оценок экспериментов с XGBoost видно, что качество классификации при использовании Bert mean pooling векторов меньше чем при использовании TfIdf векторов.

# %% [markdown]
# ## Логистическая регрессия на TfIdf

# %%
X_train, X_test, y_train, y_test = train_test_split(tf_idf_ques, ques_instr_data['instruction_num'], test_size=0.15, random_state = 123)

# %%
LR_model = LogisticRegression(max_iter = 300, random_state=123).fit(X_train,y_train)
y_pred_train_LR_tfidf = LR_model.predict_proba(X_train)
y_pred_test_LR_tfidf = LR_model.predict_proba(X_test)

# %% [markdown]
# Кросс-энтропия на train

# %%
output = log_loss(y_train, y_pred = y_pred_train_LR_tfidf, labels = range(0,11))
output
# Out:
# 1.2273659381033013

# %% [markdown]
# Кросс-энтропия на test

# %%
output = log_loss(y_test, y_pred = y_pred_test_LR_tfidf, labels = range(0,11))
output
# Out:
# 1.5659749797678735

# %% [markdown]
# RocAuc метрика на train

# %%
roc_auc_score(y_train, y_pred_train_LR_tfidf, multi_class='ovo')
# Out:
# np.float64(0.9935629178517001)

# %% [markdown]
# RocAuc метрика на test

# %%
roc_auc_score(y_test, y_pred_test_LR_tfidf, labels = range(0,11), multi_class='ovo')
# Out:
# np.float64(0.7788938492063492)

# %% [markdown]
# ## Логистическая регрессия на Bert

# %%
X_train, X_test, y_train, y_test = train_test_split(ques_mean_bert_vectors_list, ques_instr_data['instruction_num'], test_size=0.15, random_state = 123)

# %%
LR_model = LogisticRegression(max_iter = 300, random_state=123).fit(X_train,y_train)
y_pred_train_LR_bert = LR_model.predict_proba(X_train)
y_pred_test_LR_bert = LR_model.predict_proba(X_test)

# %% [markdown]
# Кросс-энтропия на train

# %%
output = log_loss(y_train, y_pred = y_pred_train_LR_bert, labels = range(0,11))
output
# Out:
# 0.09494309859083111

# %% [markdown]
# Кросс-энтропия на test

# %%
output = log_loss(y_test, y_pred = y_pred_test_LR_bert, labels = range(0,11))
output
# Out:
# 1.560025682878872

# %% [markdown]
# RocAuc метрика на train

# %%
roc_auc_score(y_train, y_pred_train_LR_bert, multi_class='ovo')
# Out:
# np.float64(0.9995330859616574)

# %% [markdown]
# RocAuc метрика на test

# %%
roc_auc_score(y_test, y_pred_test_LR_bert, labels = range(0,11), multi_class='ovo')
# Out:
# np.float64(0.7783978174603174)

# %% [markdown]
# Из приведенных выше оценок экспериментов с Логистической регрессией видно, что качество классификации при использовании Bert mean pooling векторов фактически такое же, как и при использовании TfIdf векторов.

# %% [markdown]
# ## Neural Network классификация

# %%
# функция токенизирует вопросы с помощью Bert tokenizer
UNK_IX, PAD_IX = 100, 0

def as_matrix(sequences, max_len=None):
    if max_len is None:
        max_len = min(max(map(len, list(map(str.split, sequences)))), max_len or float('inf'))

    matrix = tokenizer(sequences.tolist(), padding=True, max_length= max_len, truncation=True, add_special_tokens = False, return_tensors='pt') #

    return matrix['input_ids']

# %% [markdown]
# Максимальная длина вопроса

# %%
max_len = min(max(map(len, list(map(str.split, ques_instr_data['question_join'].values)))), max_len or float('inf'))
max_len
# Out:
# 24

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
#функция создает батчи с токенизированными вопросами
def make_batch(data, max_len=None, word_dropout=0, device=device):

    batch = {}
    batch["question"] = as_matrix(data['question_join'].values, max_len)
    batch["target"] = torch.tensor(data["instruction_num"].values, device=device)

    if word_dropout != 0:
        batch["question"] = apply_word_dropout(batch["question"], 1. - word_dropout)

    return batch

#функция делает drop out токенов с вероятностью keep_prop
def apply_word_dropout(matrix, keep_prop, replace_with=UNK_IX, pad_ix=PAD_IX):
    dropout_mask = np.random.choice(2, np.shape(matrix), p=[keep_prop, 1 - keep_prop])
    dropout_mask = dropout_mask & matrix != pad_ix
    return np.choose(dropout_mask, [matrix, np.full_like(matrix, replace_with)])

# %%
#класс классификатор вопросов с архитектурой NN
class QuestionPredictor(nn.Module):
    def __init__(self, n_tokens=tokenizer.vocab_size, hid_size=64, hid_size_l = 45):
        super().__init__()
        self.emb = nn.Embedding(n_tokens, hid_size)
        self.ques_conv1 = nn.Conv1d(hid_size, hid_size, kernel_size=3, padding='same')
        self.relu_fun = nn.ReLU()
        self.batchNorm = nn.BatchNorm1d(hid_size)
        self.ques_conv2 = nn.Conv1d(hid_size, hid_size, kernel_size=3, padding='same')
        self.out_layers = nn.Sequential(
            nn.Linear(hid_size, hid_size_l),
            nn.ReLU(),
            nn.Linear(hid_size_l, len(links)),
            nn.Softmax(dim = 1)
        )

    def forward(self, batch):
        ques_emb = self.emb(batch["question"])

        ques_emb = ques_emb.transpose(1, 2)

        ques_conv = self.ques_conv1(ques_emb) # take: (batch_size, in_channels, seq_len)

        ques_pool = F.max_pool1d(self.batchNorm(self.relu_fun(ques_conv)), 4).squeeze(-1) #ques_conv.shape[2]

        ques_conv = self.ques_conv2(ques_pool)

        ques_pool = F.max_pool1d(self.relu_fun(ques_conv), ques_conv.shape[2]).squeeze(-1)

        out = self.out_layers(ques_pool)

        return out.squeeze(-1)

# %%
model = QuestionPredictor().to(device)

# %%
data_train, data_val = train_test_split(ques_instr_data[['question_join','instruction_num']], test_size=0.15, random_state=123)

print("Train size = ", len(data_train))
print("Validation size = ", len(data_val))
# Out:
# Train size =  138
# Validation size =  25

# %%
#функция итератор мини-батчей
def iterate_minibatches(data, batch_size=35, shuffle=True, cycle=False, device=device):

    while True:
        indices = np.arange(len(data))
        if shuffle:
            indices = np.random.permutation(indices)

        for start in range(0, len(indices), batch_size):
            batch = make_batch(data.iloc[indices[start : start + batch_size]], device=device)
            yield batch

        if not cycle: break

# %%
BATCH_SIZE = 35
EPOCHS = 47

# %%
# произведем вычисление весов классов для минимизации влияния неравномерности представленных классов в выборке - используется при подсчете кросс-энтропийного лосса
class_weights = compute_class_weight('balanced',classes = np.unique(ques_instr_data['instruction_num']),y = list(ques_instr_data['instruction_num']))
class_weights = torch.tensor(class_weights,dtype=torch.float, device=device)

# %%
#функция подсчитывает и выводит на экран метрики качества f1-меру и RocAuc, а так же cross-entropy loss на валидации
def print_metrics(model, data, batch_size=BATCH_SIZE, name="", device=torch.device('cpu')):
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    ce_loss = roc_auc = f1 = num_samples = num_batches = 0.0
    model.eval()
    with torch.no_grad():
        for batch in iterate_minibatches(data, batch_size=batch_size, shuffle=False, device=device):
            batch_pred = model(batch)
            ce_loss += criterion(batch_pred, batch['target'])
            f1 += f1_score(batch['target'], y_pred = np.argmax(batch_pred, axis = 1), average = 'weighted')
            roc_auc += roc_auc_score(batch['target'], batch_pred, labels = range(0,len(links)), multi_class='ovo')
            num_samples += len(batch_pred)
            num_batches += 1
    f1 = f1 / num_batches
    roc_auc = roc_auc / num_batches
    ce_loss = ce_loss / num_batches
    print("%s results:" % (name or ""))
    print("F1: %.5f" % f1)
    print("RocAuc: %.5f" % roc_auc)
    print("CrossEntropyLoss: %.5f" % ce_loss)
    return f1, roc_auc, ce_loss

# %%
#! pip install wandb

# %%
#import wandb

# %%
#wandb.init(project="question-class-model", name="QCM27")
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250602_150422-t7x4pisn</code>
# Syncing run <strong><a href='https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn' target="_blank">QCM27</a></strong> to <a href='https://wandb.ai/nika89borisova-hse/question-class-model' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nika89borisova-hse/question-class-model' target="_blank">https://wandb.ai/nika89borisova-hse/question-class-model</a>
#  View run at <a href='https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn' target="_blank">https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# Обучение NN-модели

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
global_step = 0

for epoch in range(EPOCHS):
    print(f"epoch: {epoch}")
    model.train()
    for i, batch in tqdm(enumerate(
            iterate_minibatches(data_train, batch_size=BATCH_SIZE, device=device)),
            total=len(data_train) // BATCH_SIZE
        ):
        global_step += 1
        pred = model(batch)
        loss = criterion(pred, batch['target'])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        roc_auc = roc_auc_score(batch['target'], pred.detach().cpu().numpy(), labels = range(0,len(links)), multi_class='ovo')
        f1 = f1_score(batch['target'], y_pred = np.argmax(pred.detach().cpu().numpy(), axis = 1), average = 'weighted')
        wandb.log({"train/loss": loss.item(), "train/roc_auc": roc_auc, "train/f1": f1}, step=global_step)

    f1, roc_auc, ce_loss = print_metrics(model, data_val, device=device)
    wandb.log({"eval/loss": ce_loss, "eval/roc_auc": roc_auc, "eval/f1": f1}, step=global_step)
wandb.finish()
# Out:
# epoch: 0
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47316
# RocAuc: 0.61409
# CrossEntropyLoss: 2.24013
# epoch: 1
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.46877
# RocAuc: 0.62147
# CrossEntropyLoss: 2.24534
# epoch: 2
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.43362
# RocAuc: 0.61545
# CrossEntropyLoss: 2.26978
# epoch: 3
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.43429
# RocAuc: 0.62233
# CrossEntropyLoss: 2.25846
# epoch: 4
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.45811
# RocAuc: 0.63529
# CrossEntropyLoss: 2.23669
# epoch: 5
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47316
# RocAuc: 0.63052
# CrossEntropyLoss: 2.23315
# epoch: 6
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47316
# RocAuc: 0.62667
# CrossEntropyLoss: 2.23574
# epoch: 7
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47200
# RocAuc: 0.63411
# CrossEntropyLoss: 2.25103
# epoch: 8
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.43429
# RocAuc: 0.65166
# CrossEntropyLoss: 2.27751
# epoch: 9
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.46877
# RocAuc: 0.65706
# CrossEntropyLoss: 2.26030
# epoch: 10
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.46588
# RocAuc: 0.65079
# CrossEntropyLoss: 2.24135
# epoch: 11
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.58588
# RocAuc: 0.65414
# CrossEntropyLoss: 2.17707
# epoch: 12
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47349
# RocAuc: 0.68452
# CrossEntropyLoss: 2.16597
# epoch: 13
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47086
# RocAuc: 0.69736
# CrossEntropyLoss: 2.16353
# epoch: 14
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.46283
# RocAuc: 0.71131
# CrossEntropyLoss: 2.15606
# epoch: 15
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.45067
# RocAuc: 0.71794
# CrossEntropyLoss: 2.15524
# epoch: 16
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.69451
# CrossEntropyLoss: 2.14547
# epoch: 17
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.67107
# CrossEntropyLoss: 2.14816
# epoch: 18
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.67522
# CrossEntropyLoss: 2.15041
# epoch: 19
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.69085
# CrossEntropyLoss: 2.15119
# epoch: 20
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.48722
# RocAuc: 0.69531
# CrossEntropyLoss: 2.15252
# epoch: 21
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.48722
# RocAuc: 0.68936
# CrossEntropyLoss: 2.15338
# epoch: 22
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.68378
# CrossEntropyLoss: 2.15500
# epoch: 23
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68099
# CrossEntropyLoss: 2.15720
# epoch: 24
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68099
# CrossEntropyLoss: 2.15775
# epoch: 25
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68099
# CrossEntropyLoss: 2.15865
# epoch: 26
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68099
# CrossEntropyLoss: 2.15893
# epoch: 27
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.48322
# RocAuc: 0.68155
# CrossEntropyLoss: 2.15930
# epoch: 28
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68155
# CrossEntropyLoss: 2.15986
# epoch: 29
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68155
# CrossEntropyLoss: 2.15897
# epoch: 30
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68173
# CrossEntropyLoss: 2.15864
# epoch: 31
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.68229
# CrossEntropyLoss: 2.16030
# epoch: 32
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.69847
# CrossEntropyLoss: 2.14365
# epoch: 33
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47122
# RocAuc: 0.69017
# CrossEntropyLoss: 2.14410
# epoch: 34
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.52121
# RocAuc: 0.68198
# CrossEntropyLoss: 2.16255
# epoch: 35
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.49026
# RocAuc: 0.66908
# CrossEntropyLoss: 2.17307
# epoch: 36
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.47655
# RocAuc: 0.66741
# CrossEntropyLoss: 2.15753
# epoch: 37
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.50667
# RocAuc: 0.65960
# CrossEntropyLoss: 2.14424
# epoch: 38
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.51200
# RocAuc: 0.62605
# CrossEntropyLoss: 2.15397
# epoch: 39
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.51333
# RocAuc: 0.62444
# CrossEntropyLoss: 2.15503
# epoch: 40
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.53600
# RocAuc: 0.65160
# CrossEntropyLoss: 2.14918
# epoch: 41
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.52727
# RocAuc: 0.66592
# CrossEntropyLoss: 2.14984
# epoch: 42
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.52727
# RocAuc: 0.68136
# CrossEntropyLoss: 2.14184
# epoch: 43
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.56457
# RocAuc: 0.69085
# CrossEntropyLoss: 2.12785
# epoch: 44
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.56457
# RocAuc: 0.67597
# CrossEntropyLoss: 2.12025
# epoch: 45
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.57524
# RocAuc: 0.67597
# CrossEntropyLoss: 2.11852
# epoch: 46
#   0%|          | 0/3 [00:00<?, ?it/s]
#  results:
# F1: 0.57524
# RocAuc: 0.68452
# CrossEntropyLoss: 2.11938
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/f1</td><td>▃▃▁▁▂▃▃▁▃▂█▃▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▅▄▃▄▅▆▅▅▇▇█</td></tr><tr><td>eval/loss</td><td>▆▇█▇▆▆▇█▇▆▄▃▃▃▂▂▂▂▃▃▃▃▃▃▃▃▃▃▂▃▃▃▂▃▂▂▂▁▁▁</td></tr><tr><td>eval/roc_auc</td><td>▁▁▁▂▂▂▂▄▄▃▄▆██▆▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▅▅▄▂▄▄▆▆▅▆</td></tr><tr><td>train/f1</td><td>▃▆▄▇▂▆▃▄▆▁▅▂█▇▆▇▆█▅█▆█▅▇██▇█▇▇▇▆█▆█▇█▇██</td></tr><tr><td>train/loss</td><td>▃▄▂▅▆▂█▆▄▂▁▁▃▁▂▁▄▂▆▁▁▁▂▁▁▃▁▃▂▁▃▃▃▁▁▁▁▃▁▁</td></tr><tr><td>train/roc_auc</td><td>█▆█▆█▆▆▇▆▅█▅█▂▆█▄███▅▂▄█▅▆█▆█▃▄▅██▇█▂█▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/f1</td><td>0.57524</td></tr><tr><td>eval/loss</td><td>2.11938</td></tr><tr><td>eval/roc_auc</td><td>0.68452</td></tr><tr><td>train/f1</td><td>1</td></tr><tr><td>train/loss</td><td>1.54307</td></tr><tr><td>train/roc_auc</td><td>1</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">QCM27</strong> at: <a href='https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn' target="_blank">https://wandb.ai/nika89borisova-hse/question-class-model/runs/t7x4pisn</a><br> View project at: <a href='https://wandb.ai/nika89borisova-hse/question-class-model' target="_blank">https://wandb.ai/nika89borisova-hse/question-class-model</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250602_150422-t7x4pisn/logs</code>

# %% [markdown]
# Предсказания NN для обучающего и тестового множеств

# %%
with torch.no_grad():
    y_pred_test_nn = model(make_batch(data_val))

# %% [markdown]
# К сожалению, и с помощью NN не удалось повысить качество классификации. Попробуем проанализировать расстояние между векторными представлениями вопросов. Из теореческих размышлений можно прийти к выводу, что между вопросами одного кластера (точнее инструкции) расстояние должно быть меньше, чем между вопросами разных кластеров. Соответственно на heatmap должны быть отчетливо видны зоны малых расстояний, сгруппированные вокругглавной диагонали.

# %% [markdown]
# ## Косинусное расстояние между вопросами на векторах TfIdf

# %%
ques_tfidf_dist = pairwise_distances(tf_idf_ques, metric='cosine' )

# %%
ax_lab = np.array(list(map(str, ques_instr_data['instruction_num'].copy().values)))

for i in range(len(links)):
  indices = np.where(ax_lab == str(i))[0]
  if len(indices) > 2:
    for j in range(indices[1],indices[-1]):
      ax_lab[j] = ''

plt.rcParams.update({'font.size': 7})
plt.figure(figsize=(15, 10))
sns.heatmap(ques_tfidf_dist, xticklabels=ax_lab, yticklabels=ax_lab)
plt.show()

# %% [markdown]
# Из тепловой карты видно, что расстояние между эмбеддингами вопросов TfIdf частично коррелирует с кластерами этих вопросов, соответственно использовать такой метод для классификации новых вопросов не целесообразно.

# %% [markdown]
# ## Косинусное расстояние между вопросами на векторах Bert

# %%
ques_bert_dist = pairwise_distances(ques_mean_bert_vectors_list, metric='cosine' )

# %%
plt.rcParams.update({'font.size': 7})
plt.figure(figsize=(15, 10))
sns.heatmap(ques_bert_dist, xticklabels=ax_lab, yticklabels=ax_lab)
plt.show()

# %% [markdown]
# Из тепловой карты видно, что расстояние между эмбеддингами вопросов Bert не коррелирует с кластерами этих вопросов, соответственно использовать такой метод для классификации новых вопросов не целесообразно.

# %% [markdown]
# ## Оценки метрики Map@K

# %% [markdown]
# В DataFrame ques_instr_data_val сохраним строки валидационного множества, которые использовались на тестовом прогоне при экспериментах на моделях XGBoost и NN.

# %%
ques_instr_data_val = ques_instr_data.iloc[data_val.index].copy()

# %% [markdown]
# Следующий код добавляет столбцы в ques_instr_data_val с оценками метрики map@K для результатов экспериментов  с методами XGBoost, логистической регрессии и NN.

# %%
create_pred_mapK_cols(ques_instr_data_val, y_pred_test_XGB_tfidf, data_val.index, 'XGB_tfidf', K, inverse = True)
create_pred_mapK_cols(ques_instr_data_val, y_pred_test_XGB_bert, data_val.index, 'XGB_bert', K, inverse = True)
create_pred_mapK_cols(ques_instr_data_val, y_pred_test_nn, data_val.index, 'nn', K, inverse = True)

# %%
create_pred_mapK_cols(ques_instr_data_val, y_pred_test_LR_tfidf, data_val.index, 'LR_tfidf', K, inverse = True)
create_pred_mapK_cols(ques_instr_data_val, y_pred_test_LR_bert, data_val.index, 'LR_bert', K, inverse = True)

# %% [markdown]
# Приведем оценки метрики Map@K для каждого из рассмотреных методов на валидационном множестве.

# %%
mean_mapK = ques_instr_data_val[mapK_cols].mean()
mean_mapK.rename('mean', inplace=True).sort_values(ascending=False, inplace=True)
mean_mapK
# Out:
# map@K_tfidf_cosine           0.72
# map@K_LR_bert                0.60
# map@K_LR_tfidf               0.60
# map@K_XGB_bert               0.54
# map@K_XGB_tfidf              0.52
# map@K_nn                     0.50
# map@K_max_bert_cosine        0.42
# map@K_mean_bert_manhattan    0.38
# map@K_mean_bert_cosine       0.36
# map@K_max_bert_manhattan     0.34
# map@K_tfidf_manhattan        0.02
# Name: mean, dtype: float64

# %% [markdown]
# Из приведенной выше таблицы видно, что наилучший результат классификации вопроса к инструкции удалось получить, оценивая косинусное расстояние между представлениями TfIdf вопросов и инструкций. Следующим по качеству идет классификация методом логистической регрессии, которая дала равные оценки метрики Map@K как на TfIdf представлении, так и на эмбеддингах Bert.
